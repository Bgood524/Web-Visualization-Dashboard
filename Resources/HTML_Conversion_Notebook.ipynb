# %%
import pandas as pd

# %%
fpath = pd.read_csv('weather_data.csv')

# %%
fpath.drop(columns=['Unnamed: 0'])
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Souillac -20.5167   57.5167    294.46        81          13
# 1         Rikitea -23.1203 -134.9692    296.25        73          64
# 2            Kaeo -35.1000  173.7833    288.89        97         100
# 3       Busselton -33.6500  115.3333    284.31        83         100
# 4            Lebu -37.6167  -73.6500    284.33        68           1
# ..            ...      ...       ...       ...       ...         ...
# 585       Ladário -19.0047  -57.6017    299.31        65          20
# 586  Mt. Pleasant  32.7941  -79.8626    303.23        78          20
# 587          Yate  51.5407   -2.4184    296.53        71          10
# 588       Labuhan  -6.8844  112.2051    300.69        73          75
# 589         Lucea  18.4510  -78.1736    303.63        71         100
#
#      Wind Speed Country        Date
# 0          4.78      MU  1631718069
# 1          7.59      PF  1631718277
# ...

# %%
weather_data_html = fpath.to_html()

# %%
print(weather_data_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Souillac</td>
#       <td>-20.5167</td>
#       <td>57.5167</td>
#       <td>294.46</td>
#       <td>81</td>
#       <td>13</td>
#       <td>4.78</td>
#       <td>MU</td>
#       <td>1631718069</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Rikitea</td>
#       <td>-23.1203</td>
#       <td>-134.9692</td>
#       <td>296.25</td>
#       <td>73</td>
#       <td>64</td>
#       <td>7.59</td>
#       <td>PF</td>
#       <td>1631718277</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...
